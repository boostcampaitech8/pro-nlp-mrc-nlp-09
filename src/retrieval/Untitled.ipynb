# %%
import os

base_path = "./outputs/sehun"

for name in ["question_encoder", "context_encoder"]:
    folder = os.path.join(base_path, name)
    print(f"\n=== {folder} ===")
    if os.path.exists(folder):
        print("Exists.")
        print("Files:", os.listdir(folder))
    else:
        print("❌ DOES NOT EXIST")
# Out:
# === ./outputs/sehun/question_encoder ===
# ❌ DOES NOT EXIST
#
# === ./outputs/sehun/context_encoder ===
# ❌ DOES NOT EXIST
